# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-100,100,100)

recta =x**2 + 4*x + 7

plt.figure(figsize=(10,6))

plt.plot(x,recta,label="y=2x+5",linewidth = 2.4, color = "purple", linestyle = "--")
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")
plt.axhline(0,color = "black",linestyle="--")
plt.axvline(0,color = "black",linestyle="--")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-95,100,100)

recta =(x-3)**2 - 9

plt.figure(figsize=(10,6))

plt.plot(x,)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
e=np.linspace(-100,100,100)
x=np.linspace(-100,100,100)

recta =4 * e**x

plt.figure(figsize=(10,6))

plt.plot(x,recta",linewidth = 2.4, color = "purple", linestyle = "--")
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")

plt.show()
# Out:
# C:\Users\EMA 4 - 207\AppData\Local\Temp\ipykernel_9700\40233789.py:6: RuntimeWarning: invalid value encountered in power
#   recta =4 * e**x

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-1000,1000,1000)

recta =-(x + 5)**2 + 3

plt.figure(figsize=(10,6))

plt.plot(x,recta,linewidth = 2.4, color = "purple",)
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")
plt.axhline(0,color = "black",linestyle="--")
plt.axvline(0,color = "black",linestyle="--")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x=np.linspace(-2090,990,9999)

recta = (4 * x - 5)**0.5 + 3

plt.figure(figsize=(10,6))

plt.plot(x,recta,linewidth = 2.4, color = "purple")
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")
plt.axhline(0,color = "black",linestyle="--")
plt.axvline(0,color = "black",linestyle="--")
plt.show()
# Out:
# C:\Users\EMA 4 - 207\AppData\Local\Temp\ipykernel_9700\3574306704.py:7: RuntimeWarning: invalid value encountered in sqrt
#   recta = (4 * x - 5)**0.5 + 3

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-9999,320,9999)

recta =-(20 - 4 * x)**0.5 - 3

plt.figure(figsize=(10,6))

plt.plot(x,recta,label="y=2x+5",linewidth = 2.4, color = "purple")
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")
plt.axhline(0,color = "black",linestyle="--")
plt.axvline(0,color = "black",linestyle="--")
plt.show()
# Out:
# C:\Users\EMA 4 - 207\AppData\Local\Temp\ipykernel_9700\3545533586.py:6: RuntimeWarning: invalid value encountered in sqrt
#   recta =-(20 - 4 * x)**0.5 - 3

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-1200,990,700)

recta =-(3 * x + 15)**0.5 + 7

plt.figure(figsize=(10,6))

plt.plot(x,recta,linewidth = 2.4, color = "purple")
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")
plt.axhline(0,color = "black",linestyle="--")
plt.axvline(0,color = "black",linestyle="--")
plt.show()
# Out:
# C:\Users\EMA 4 - 207\AppData\Local\Temp\ipykernel_9700\3058568051.py:6: RuntimeWarning: invalid value encountered in sqrt
#   recta =-(3 * x + 15)**0.5 + 7

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.linspace(-100,100,100)

recta =-(20 - 4 * x)**0.5 - 3

plt.figure(figsize=(10,6))

plt.plot(x,recta,label="y=2x+5",linewidth = 2.4, color = "purple")
plt.title("GRAFICA DE UNA PARABOLA")
plt.xlabel("valores de x")
plt.ylabel("valores de y")
plt.axhline(0,color = "black",linestyle="--")
plt.axvline(0,color = "black",linestyle="--")
plt.show()
